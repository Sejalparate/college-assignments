# %%
import nltk
from PyPDF2 import PdfReader

# %%
reader = PdfReader('Corpus.pdf')
page = reader.pages[0] 
text = page.extract_text()

# %%
grammar = '\n'.join([
    'NP: {<DT>*<NN>+}',
    'NP: {<DT>*<NNP>+}',
    'NP: {<DT>*<NNS>+}',
    'ADJP: {<DT>*<JJ>+}',
    'ADJP: {<VBZ>*<JJ>}',
    'ADJP: {<DT>*<JJ><CC><JJ>+}',
    'ADVP: {<RB>+}',
    'VP: {<VBZ>*<VB>}',
    'VP: {<VBZ>*<VBD>}',
    'VP: {<VBZ>*<VBN>}',
    'VP: {<DT>*<NN>*<VB>}',
    'PP: {<IN>}'])

# %% [markdown]
# ## Using grammar

# %%
tokens = nltk.word_tokenize(text)
print(tokens)
# Out:
# ['What', 'is', 'my', 'happy', 'place', '?', '→', 'Close', 'your', 'eyes', 'and', 'feel', 'this', 'every', 'moment', '.', 'Let', 'it', 'heal', 'you', '!', 'It', 'covers', 'all', 'the', 'important', 'points', 'in', 'your', 'bucket', 'list', '.', 'You', 'are', 'in', 'Iceland', '.', 'There', 'is', 'a', 'beautiful', 'mountain', 'and', 'through', 'the', 'edge', ',', 'you', 'can', 'see', 'a', 'pool', 'of', 'water', '.', 'Sun', 'rays', 'bouncing', 'over', 'bits', 'of', 'glaciers', ',', 'giving', 'a', 'hint', 'of', 'blue', 'to', 'the', 'white', 'snow', '.', 'On', 'the', 'opposite', 'side', ',', 'there', 'is', 'a', 'sharp', 'cliff', 'with', 'beautifully', 'segmented', 'vertical', 'bamboo', '-like', 'rocks', '.', 'Just', 'like', 'this…', '.', 'You', 'are', 'wearing', 'your', 'favourite', 'winter', 'clothing', '–', 'a', 'beanie', ',', 'a', 'jacket', 'pulled', 'over', 'a', 'cardigan', ',', 'scarf', ',', 'snow', 'boots', ',', 'a', 'pair', 'of', 'mittens', 'and', 'are', 'set', 'to', 'build', 'a', 'tent', 'near', 'the', 'edge', '.', 'Once', ',', 'you', 'finish', 'building', 'the', 'tent', ',', 'you', 'go', 'and', 'fetch', 'for', 'some', 'firewood', ',', 'before', 'it', 'starts', 'getting', 'dark', '.', 'You', 'bring', 'them', 'back', 'to', 'your', 'tent', ',', 'and', 'pile', 'them', 'up', 'to', 'set', 'it', 'on', 'fire', '.', 'You', 'place', 'your', 'arm', 'chair', 'in', 'front', 'of', 'your', 'tent', ',', 'with', 'the', 'campfire', 'lit', 'beside', 'you', ',', 'and', 'finally', 'gasp', 'in', 'your', 'breath', '.', 'You', 'put', 'on', 'your', 'headphones', 'and', 'play', 'your', 'favourite', 'p', 'laylist', '!', '(', 'No', 'song', 'interruptions', ',', 'because', 'you', 'have', 'got', 'Spotify', 'premium', '>', '<', ')', '.', 'You', 'just', 'close', 'your', 'eyes', 'for', 'a', 'moment', ',', 'and', 'no', 'thoughts', 'flow', 'into', 'your', 'mind', ',', 'which', 'strangely', 'remains', 'unnoticed', '.', 'You', 'open', 'your', 'eyes', 'to', 'see', 'the', 'sun', 'gazing', 'onto', 'your', 'eyes', 'through', 'the', 'clouds', '.', 'As', 'it', 'starts', 'setting', 'down', ',', 'the', 'colour', 'of', 'the', 'sky', 'changes', 'to', 'a', 'beautiful', 'sunset', 'gradient', 'fill', '.', 'The', 'sun', 'hides', 'behind', 'a', 'few', 'clouds', 'again', ',', 'and', 'you', 'can', 'see', 'the', 'light', 'scattering', 'all', 'around', '.', 'You', 'set', 'the', 'tripod', 'stand', 'for', 'your', 'DSLR', 'camera', ',', 'make', 'the', 'specifications', 'to', 'capture', 'the', 'moment', ',', 'and', 'start', 'recording', 'a', 'timelapse', 'of', 'the', 'sky', '.', 'You', 'just', 'don', '’', 't', 'want', 'to', 'be', 'distracted', 'by', 'anything', 'else', ',', 'so', 'you', 'stop', 'playing', 'the', 'songs', ',', 'and', 'enjoy', 'the', 'silent', ',', 'peacef', 'ul', 'moment', '!', 'Finally', ',', 'the', 'sun', 'sets', 'and', 'brightness', 'starts', 'fading', 'away', 'as', 'the', 'night', 'falls', '.', 'You', 'see', 'pecks', 'of', 'lights', '(', 'stars', ')', 'in', 'the', 'dusk', 'background', '.', 'You', 'have', 'never', 'seen', 'so', 'many', 'stars', 'on', 'nightfall', ',', 'and', 'it', 'totally', 'amazes', 'you', '.', 'You', 'see', 'the', 'crescent', 'moon', 'hovering', 'over', 'your', 'head', 'so', 'clear', ',', 'that', 'you', 'can', 'make', 'out', 'its', 'craters', '!', 'You', 'decide', 'to', 'take', 'a', 'closer', 'lo', 'ok', 'and', 'stand', 'on', 'the', 'edge', 'of', 'the', 'cliff', '.', 'You', 'look', 'down', 'upon', 'at', 'the', 'pool', 'of', 'water', ',', 'just', 'to', 'surprise', 'yourself', 'with', 'the', 'presence', 'of', 'sparkling', 'water', '.', 'Later', 'on', 'you', 'realise', 'that', 'it', '’', 's']

# %%
tags = nltk.pos_tag(tokens)
print(tags)
# Out:
# [('What', 'WP'), ('is', 'VBZ'), ('my', 'PRP$'), ('happy', 'JJ'), ('place', 'NN'), ('?', '.'), ('→', 'UH'), ('Close', 'NNP'), ('your', 'PRP$'), ('eyes', 'NNS'), ('and', 'CC'), ('feel', 'VB'), ('this', 'DT'), ('every', 'DT'), ('moment', 'NN'), ('.', '.'), ('Let', 'VB'), ('it', 'PRP'), ('heal', 'VB'), ('you', 'PRP'), ('!', '.'), ('It', 'PRP'), ('covers', 'VBZ'), ('all', 'PDT'), ('the', 'DT'), ('important', 'JJ'), ('points', 'NNS'), ('in', 'IN'), ('your', 'PRP$'), ('bucket', 'NN'), ('list', 'NN'), ('.', '.'), ('You', 'PRP'), ('are', 'VBP'), ('in', 'IN'), ('Iceland', 'NNP'), ('.', '.'), ('There', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('mountain', 'NN'), ('and', 'CC'), ('through', 'IN'), ('the', 'DT'), ('edge', 'NN'), (',', ','), ('you', 'PRP'), ('can', 'MD'), ('see', 'VB'), ('a', 'DT'), ('pool', 'NN'), ('of', 'IN'), ('water', 'NN'), ('.', '.'), ('Sun', 'NNP'), ('rays', 'VBZ'), ('bouncing', 'NN'), ('over', 'IN'), ('bits', 'NNS'), ('of', 'IN'), ('glaciers', 'NNS'), (',', ','), ('giving', 'VBG'), ('a', 'DT'), ('hint', 'NN'), ('of', 'IN'), ('blue', 'NN'), ('to', 'TO'), ('the', 'DT'), ('white', 'JJ'), ('snow', 'NN'), ('.', '.'), ('On', 'IN'), ('the', 'DT'), ('opposite', 'JJ'), ('side', 'NN'), (',', ','), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('sharp', 'JJ'), ('cliff', 'NN'), ('with', 'IN'), ('beautifully', 'RB'), ('segmented', 'VBN'), ('vertical', 'JJ'), ('bamboo', 'NN'), ('-like', 'NN'), ('rocks', 'NNS'), ('.', '.'), ('Just', 'NNP'), ('like', 'IN'), ('this…', 'NN'), ('.', '.'), ('You', 'PRP'), ('are', 'VBP'), ('wearing', 'VBG'), ('your', 'PRP$'), ('favourite', 'JJ'), ('winter', 'NN'), ('clothing', 'NN'), ('–', 'VBZ'), ('a', 'DT'), ('beanie', 'NN'), (',', ','), ('a', 'DT'), ('jacket', 'NN'), ('pulled', 'VBD'), ('over', 'RP'), ('a', 'DT'), ('cardigan', 'NN'), (',', ','), ('scarf', 'NN'), (',', ','), ('snow', 'JJ'), ('boots', 'NNS'), (',', ','), ('a', 'DT'), ('pair', 'NN'), ('of', 'IN'), ('mittens', 'NNS'), ('and', 'CC'), ('are', 'VBP'), ('set', 'VBN'), ('to', 'TO'), ('build', 'VB'), ('a', 'DT'), ('tent', 'NN'), ('near', 'IN'), ('the', 'DT'), ('edge', 'NN'), ('.', '.'), ('Once', 'RB'), (',', ','), ('you', 'PRP'), ('finish', 'VBP'), ('building', 'VBG'), ('the', 'DT'), ('tent', 'NN'), (',', ','), ('you', 'PRP'), ('go', 'VBP'), ('and', 'CC'), ('fetch', 'VBP'), ('for', 'IN'), ('some', 'DT'), ('firewood', 'NN'), (',', ','), ('before', 'IN'), ('it', 'PRP'), ('starts', 'VBZ'), ('getting', 'VBG'), ('dark', 'NN'), ('.', '.'), ('You', 'PRP'), ('bring', 'VBP'), ('them', 'PRP'), ('back', 'RB'), ('to', 'TO'), ('your', 'PRP$'), ('tent', 'NN'), (',', ','), ('and', 'CC'), ('pile', 'VB'), ('them', 'PRP'), ('up', 'RP'), ('to', 'TO'), ('set', 'VB'), ('it', 'PRP'), ('on', 'IN'), ('fire', 'NN'), ('.', '.'), ('You', 'PRP'), ('place', 'VBP'), ('your', 'PRP$'), ('arm', 'NN'), ('chair', 'NN'), ('in', 'IN'), ('front', 'NN'), ('of', 'IN'), ('your', 'PRP$'), ('tent', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), ('campfire', 'NN'), ('lit', 'NN'), ('beside', 'IN'), ('you', 'PRP'), (',', ','), ('and', 'CC'), ('finally', 'RB'), ('gasp', 'VB'), ('in', 'IN'), ('your', 'PRP$'), ('breath', 'NN'), ('.', '.'), ('You', 'PRP'), ('put', 'VBP'), ('on', 'IN'), ('your', 'PRP$'), ('headphones', 'NNS'), ('and', 'CC'), ('play', 'VB'), ('your', 'PRP$'), ('favourite', 'JJ'), ('p', 'JJ'), ('laylist', 'NN'), ('!', '.'), ('(', '('), ('No', 'UH'), ('song', 'NN'), ('interruptions', 'NNS'), (',', ','), ('because', 'IN'), ('you', 'PRP'), ('have', 'VBP'), ('got', 'VBN'), ('Spotify', 'NNP'), ('premium', 'JJ'), ('>', 'NNP'), ('<', 'NNP'), (')', ')'), ('.', '.'), ('You', 'PRP'), ('just', 'RB'), ('close', 'VB'), ('your', 'PRP$'), ('eyes', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('moment', 'NN'), (',', ','), ('and', 'CC'), ('no', 'DT'), ('thoughts', 'NNS'), ('flow', 'VBP'), ('into', 'IN'), ('your', 'PRP$'), ('mind', 'NN'), (',', ','), ('which', 'WDT'), ('strangely', 'RB'), ('remains', 'VBZ'), ('unnoticed', 'JJ'), ('.', '.'), ('You', 'PRP'), ('open', 'VBP'), ('your', 'PRP$') ...

# %%
chunkparser = nltk.RegexpParser(grammar)
result = chunkparser.parse(tags)
print(result)
# Out:
# (S
#   What/WP
#   is/VBZ
#   my/PRP$
#   (ADJP happy/JJ)
#   (NP place/NN)
#   ?/.
#   →/UH
#   (NP Close/NNP)
#   your/PRP$
#   (NP eyes/NNS)
#   and/CC
#   (VP feel/VB)
#   (NP this/DT every/DT moment/NN)
#   ./.
#   (VP Let/VB)
#   it/PRP
#   (VP heal/VB)
#   you/PRP
#   !/.
#   It/PRP
#   covers/VBZ
#   all/PDT
#   (ADJP the/DT important/JJ)
#   (NP points/NNS)
#   (PP in/IN)
#   your/PRP$
#   (NP bucket/NN list/NN)
#   ./.
#   You/PRP
#   are/VBP
#   (PP in/IN)
#   (NP Iceland/NNP)
#   ./.
#   There/EX
#   is/VBZ
#   (ADJP a/DT beautiful/JJ)
#   (NP mountain/NN)
#   and/CC
#   (PP through/IN)
#   (NP the/DT edge/NN)
#   ,/,
#   you/PRP
#   can/MD
#   (VP see/VB)
#   (NP a/DT pool/NN)
#   (PP of/IN)
#   (NP water/NN)
#   ./.
#   (NP Sun/NNP)
#   rays/VBZ
#   (NP bouncing/NN)
#   (PP over/IN)
#   (NP bits/NNS)
#   (PP of/IN)
#   (NP glaciers/NNS)
#   ,/,
#   giving/VBG
#   (NP a/DT hint/NN)
#   (PP of/IN)
#   (NP blue/NN)
#   to/TO
#   (ADJP the/DT white/JJ)
#   (NP snow/NN)
#   ./.
#   (PP On/IN)
#   (ADJP the/DT opposite/JJ)
#   (NP side/NN)
#   ,/,
#   there/EX
#   is/VBZ
#   (ADJP a/DT sharp/JJ)
#   (NP cliff/NN)
#   (PP with/IN)
#   (ADVP beautifully/RB)
#   (VP segmented/VBN)
#   (ADJP vertical/JJ)
#   (NP bamboo/NN -like/NN)
#   (NP rocks/NNS)
#   ./.
#   (NP Just/NNP)
#   (PP like/IN)
#   (NP this…/NN)
#   ./.
#   You/PRP
#   are/VBP
#   wearing/VBG
#   your/PRP$
#   (ADJP favourite/JJ)
#   (NP winter/NN clothing/NN)
#   –/VBZ
#   (NP a/DT beanie/NN)
#   ,/,
#   (NP a/DT jacket/NN)
#   (VP pulled/VBD)
#   over/RP
#   (NP a/DT cardigan/NN)
#   ,/,
#   (NP scarf/NN)
#   ,/,
#   (ADJP snow/JJ)
#   (NP boots/NNS)
#   ,/,
#   (NP a/DT pair/NN)
#   (PP of/IN)
#   (NP mittens/NNS)
#   and/CC
#   are/VBP
#   (VP set/VBN)
#   to/TO
#   (VP build/VB)
#   (NP a/DT tent/NN)
#   (PP near/IN)
#   (NP the/DT edge/NN)
#   ./.
#   (ADVP Once/RB)
#   ,/,
#   you/PRP
#   finish/VBP
#   building/VBG
#   (NP the/DT tent/NN)
#   ,/,
#   you/PRP
#   go/VBP
#   and/CC
#   fetch/VBP
#   (PP for/IN)
#   (NP some/DT firewood/NN)
#   ,/,
#   (PP before/IN)
#   it/PRP
#   starts/VBZ
#   getting/VBG
#   (NP dark/NN)
#   ./.
#   You/PRP
#   bring/VBP
#   them/PRP
#   (ADVP back/RB)
#   to/TO
#   your/PRP$
#   (NP tent/NN)
#   ,/,
#   and/CC
#   (VP pile/VB)
#   them/PRP
#   up/RP
#   to/TO
#   (VP set/VB)
#   it/PRP
#   (PP on/IN)
#   (NP fire/NN)
#   ./.
#   You/PRP
#   place/VBP
#   your/PRP$
#   (NP arm/NN chair/NN)
#   (PP in/IN)
#   (NP front/NN)
#   (PP of/IN)
#   your/PRP$
#   (NP tent/NN)
#   ,/,
#   (PP with/IN)
#   (NP the/DT campfire/NN lit/NN)
#   (PP beside/IN)
#   you/PRP
#   ,/,
#   and/CC
#   (ADVP finally/RB)
#   (VP gasp/VB)
#   (PP in/IN)
#   your/PRP$
#   (NP breath/NN)
#   ./.
#   You/PRP
#   put/VBP
#   (PP on/IN)
#   your/PRP$
#   (NP headphones/NNS)
#   and/CC
#   (VP play/VB)
#   your/PRP$
#   (ADJP favourite/JJ p/JJ)
#   (NP laylist/NN)
#   !/.
#   (/(
#   No/UH
#   (NP song/NN)
#   (NP interruptions/NNS)
#   ,/,
#   (PP because/IN)
#   you/PRP
#   have/VBP
#   (VP got/VBN)
#   (NP Spotify/NNP)
#   (ADJP premium/JJ)
#   (NP >/NNP </NNP)
#   )/)
#   ./.
#   You/PRP
#   (ADVP just/RB)
#   (VP close/VB)
#   your/PRP$
#   (NP eyes/NNS)
#   (PP for/IN)
#   (NP a/DT moment/NN)
#   ,/,
#   and/CC
#   (NP no/DT thoughts/NNS)
#   flow/VBP
#   (PP into/IN)
#   your/PRP$
#   (NP mind/NN)
#   ,/,
#   which/WDT
#   (ADVP strangely/RB)
#   remains/VBZ
#   (ADJP unnoticed/JJ)
#   ./.
#   You/PRP
#   open/VBP
#   your/PRP$
#   (NP eyes/NNS)
#   to/TO
#   (VP see/VB)
#   (NP the/DT sun/NN)
#   gazing/VBG
#   (PP onto/IN)
#   your/PRP$
#   (NP eyes/NNS)
#   (PP through/IN)
#   (NP the/DT clouds/NN)
#   ./.
#   (PP As/IN)
#   it/PRP
#   starts/VBZ
#   setting/VBG
#   down/RP
#   ,/,
#   (NP the/DT colour/NN)
#   (PP of/IN)
#   (NP the/DT sky/NN)
#   (NP changes/NNS)
#   to/TO
#   (ADJP a/DT beautiful/JJ)
#   (NP sunset/NN gradient/NN fill/NN)
#   ./.
#   (NP The/DT sun/NN)
#   (NP hides/NNS)
#   (PP behind/IN)
#   (ADJP a/DT few/JJ)
#   (NP clouds/NN)
#   (ADVP again/RB)
#   ,/,
#   and/CC
#   you/PRP
#   can/MD
#   (VP see/VB)
#   (ADJP the/DT light/JJ)
#   scattering/VBG
#   all/DT
#   (ADVP around/RB)
#   ./.
#   You/PRP
#   set/VBP
#   (NP the/DT tripod/NN stand/NN)
#   (PP for/IN)
#   your/PRP$
#   (NP DSLR/NNP)
#   (NP camera/NN)
#   ,/,
#   make/VBP
#   (NP the/DT specifications/NNS)
#   to/TO
#   (VP capture/VB)
#   (NP the/DT moment/NN)
#   ,/,
#   and/CC
#   (VP start/VB)
#   recording/VBG
#   (NP a/DT timelapse/NN)
#   (PP of/IN)
#   (NP the/DT sky/NN)
#   ./.
#   You/PRP
#   (ADVP just/RB)
#   (VP don/VB)
#   (ADJP ’/JJ)
#   (NP t/NN)
#   want/VBP
#   to/TO
#   (VP be/VB)
#   (VP distracted/VBN)
#   (PP by/IN)
#   (NP anything/NN)
#   (ADVP else/RB)
#   ,/,
#   (PP so/IN)
#   you/PRP
#   stop/VBP
#   playing/VBG
#   (NP the/DT songs/NNS)
#   ,/,
#   and/CC
#   (VP enjoy/VB)
#   (NP the/DT silent/NN)
#   ,/,
#   (NP peacef/NN)
#   (ADJP ul/JJ)
#   (NP moment/NN)
#   !/.
#   (ADVP Finally/RB)
#   ,/,
#   (NP the/DT sun/NN)
#   (NP sets/NNS)
#   and/CC
#   (NP brightness/NN)
#   (NP starts/NNS)
#   fading/VBG
#   (ADVP away/RB)
#   (PP as/IN)
#   (NP the/DT night/NN)
#   falls/VBZ
#   ./.
#   You/PRP
#   see/VBP
#   (NP pecks/NNS)
#   (PP of/IN)
#   (NP lights/NNS)
#   (/(
#   (NP stars/NNS)
#   )/)
#   (PP in/IN)
#   (NP the/DT dusk/NN background/NN)
#   ./.
#   You/PRP
#   have/VBP
#   (ADVP never/RB)
#   (VP seen/VBN)
#   (ADVP so/RB)
#   (ADJP many/JJ)
#   (NP stars/NNS)
#   (PP on/IN)
#   (NP nightfall/NN)
#   ,/,
#   and/CC
#   it/PRP
#   (ADVP totally/RB)
#   amazes/VBZ
#   you/PRP
#   ./.
#   You/PRP
#   see/VBP
#   (NP the/DT crescent/NN moon/NN)
#   hovering/VBG
#   (PP over/IN)
#   your/PRP$
#   (NP head/NN)
#   (ADVP so/RB)
#   (ADJP clear/JJ)
#   ,/,
#   (PP that/IN)
#   you/PRP
#   can/MD
#   (VP make/VB)
#   out/RP
#   its/PRP$
#   (NP craters/NNS)
#   !/.
#   You/PRP
#   decide/VBP
#   to/TO
#   (VP take/VB)
#   a/DT
#   closer/JJR
#   (ADJP lo/JJ)
#   (NP ok/NN)
#   and/CC
#   (VP stand/VB)
#   (PP on/IN)
#   (NP the/DT edge/NN)
#   (PP of/IN)
#   (NP the/DT cliff/NN)
#   ./.
#   You/PRP
#   look/VBP
#   down/RP
#   (ADVP upon/RB)
#   (PP at/IN)
#   (NP the/DT pool/NN)
#   (PP of/IN)
#   (NP water/NN)
#   ,/,
#   (ADVP just/RB)
#   to/TO
#   (VP surprise/VB)
#   yourself/PRP
#   (PP with/IN)
#   (NP the/DT presence/NN)
#   (PP of/IN)
#   (ADJP sparkling/JJ)
#   (NP water/NN)
#   ./.
#   (ADVP Later/RB)
#   (PP on/IN)
#   you/PRP
#   realise/VBP
#   (PP that/IN)
#   it/PRP
#   ’/VBZ
#   (NP s/NN))

# %% [markdown]
# ## Using in-built functions

# %%
class CustomChunker(nltk.chunk.ChunkParserI):
    def __init__(self, grammar):
        self.chunk_parser = nltk.RegexpParser(grammar)

    def parse(self, tagged_sentence):
        chunks = self.chunk_parser.parse(tagged_sentence)
        return chunks

# %%
custom_chunker = CustomChunker(grammar)
chunks = custom_chunker.parse(tags)
print(chunks)
# Out:
# (S
#   What/WP
#   is/VBZ
#   my/PRP$
#   (ADJP happy/JJ)
#   (NP place/NN)
#   ?/.
#   →/UH
#   (NP Close/NNP)
#   your/PRP$
#   (NP eyes/NNS)
#   and/CC
#   (VP feel/VB)
#   (NP this/DT every/DT moment/NN)
#   ./.
#   (VP Let/VB)
#   it/PRP
#   (VP heal/VB)
#   you/PRP
#   !/.
#   It/PRP
#   covers/VBZ
#   all/PDT
#   (ADJP the/DT important/JJ)
#   (NP points/NNS)
#   (PP in/IN)
#   your/PRP$
#   (NP bucket/NN list/NN)
#   ./.
#   You/PRP
#   are/VBP
#   (PP in/IN)
#   (NP Iceland/NNP)
#   ./.
#   There/EX
#   is/VBZ
#   (ADJP a/DT beautiful/JJ)
#   (NP mountain/NN)
#   and/CC
#   (PP through/IN)
#   (NP the/DT edge/NN)
#   ,/,
#   you/PRP
#   can/MD
#   (VP see/VB)
#   (NP a/DT pool/NN)
#   (PP of/IN)
#   (NP water/NN)
#   ./.
#   (NP Sun/NNP)
#   rays/VBZ
#   (NP bouncing/NN)
#   (PP over/IN)
#   (NP bits/NNS)
#   (PP of/IN)
#   (NP glaciers/NNS)
#   ,/,
#   giving/VBG
#   (NP a/DT hint/NN)
#   (PP of/IN)
#   (NP blue/NN)
#   to/TO
#   (ADJP the/DT white/JJ)
#   (NP snow/NN)
#   ./.
#   (PP On/IN)
#   (ADJP the/DT opposite/JJ)
#   (NP side/NN)
#   ,/,
#   there/EX
#   is/VBZ
#   (ADJP a/DT sharp/JJ)
#   (NP cliff/NN)
#   (PP with/IN)
#   (ADVP beautifully/RB)
#   (VP segmented/VBN)
#   (ADJP vertical/JJ)
#   (NP bamboo/NN -like/NN)
#   (NP rocks/NNS)
#   ./.
#   (NP Just/NNP)
#   (PP like/IN)
#   (NP this…/NN)
#   ./.
#   You/PRP
#   are/VBP
#   wearing/VBG
#   your/PRP$
#   (ADJP favourite/JJ)
#   (NP winter/NN clothing/NN)
#   –/VBZ
#   (NP a/DT beanie/NN)
#   ,/,
#   (NP a/DT jacket/NN)
#   (VP pulled/VBD)
#   over/RP
#   (NP a/DT cardigan/NN)
#   ,/,
#   (NP scarf/NN)
#   ,/,
#   (ADJP snow/JJ)
#   (NP boots/NNS)
#   ,/,
#   (NP a/DT pair/NN)
#   (PP of/IN)
#   (NP mittens/NNS)
#   and/CC
#   are/VBP
#   (VP set/VBN)
#   to/TO
#   (VP build/VB)
#   (NP a/DT tent/NN)
#   (PP near/IN)
#   (NP the/DT edge/NN)
#   ./.
#   (ADVP Once/RB)
#   ,/,
#   you/PRP
#   finish/VBP
#   building/VBG
#   (NP the/DT tent/NN)
#   ,/,
#   you/PRP
#   go/VBP
#   and/CC
#   fetch/VBP
#   (PP for/IN)
#   (NP some/DT firewood/NN)
#   ,/,
#   (PP before/IN)
#   it/PRP
#   starts/VBZ
#   getting/VBG
#   (NP dark/NN)
#   ./.
#   You/PRP
#   bring/VBP
#   them/PRP
#   (ADVP back/RB)
#   to/TO
#   your/PRP$
#   (NP tent/NN)
#   ,/,
#   and/CC
#   (VP pile/VB)
#   them/PRP
#   up/RP
#   to/TO
#   (VP set/VB)
#   it/PRP
#   (PP on/IN)
#   (NP fire/NN)
#   ./.
#   You/PRP
#   place/VBP
#   your/PRP$
#   (NP arm/NN chair/NN)
#   (PP in/IN)
#   (NP front/NN)
#   (PP of/IN)
#   your/PRP$
#   (NP tent/NN)
#   ,/,
#   (PP with/IN)
#   (NP the/DT campfire/NN lit/NN)
#   (PP beside/IN)
#   you/PRP
#   ,/,
#   and/CC
#   (ADVP finally/RB)
#   (VP gasp/VB)
#   (PP in/IN)
#   your/PRP$
#   (NP breath/NN)
#   ./.
#   You/PRP
#   put/VBP
#   (PP on/IN)
#   your/PRP$
#   (NP headphones/NNS)
#   and/CC
#   (VP play/VB)
#   your/PRP$
#   (ADJP favourite/JJ p/JJ)
#   (NP laylist/NN)
#   !/.
#   (/(
#   No/UH
#   (NP song/NN)
#   (NP interruptions/NNS)
#   ,/,
#   (PP because/IN)
#   you/PRP
#   have/VBP
#   (VP got/VBN)
#   (NP Spotify/NNP)
#   (ADJP premium/JJ)
#   (NP >/NNP </NNP)
#   )/)
#   ./.
#   You/PRP
#   (ADVP just/RB)
#   (VP close/VB)
#   your/PRP$
#   (NP eyes/NNS)
#   (PP for/IN)
#   (NP a/DT moment/NN)
#   ,/,
#   and/CC
#   (NP no/DT thoughts/NNS)
#   flow/VBP
#   (PP into/IN)
#   your/PRP$
#   (NP mind/NN)
#   ,/,
#   which/WDT
#   (ADVP strangely/RB)
#   remains/VBZ
#   (ADJP unnoticed/JJ)
#   ./.
#   You/PRP
#   open/VBP
#   your/PRP$
#   (NP eyes/NNS)
#   to/TO
#   (VP see/VB)
#   (NP the/DT sun/NN)
#   gazing/VBG
#   (PP onto/IN)
#   your/PRP$
#   (NP eyes/NNS)
#   (PP through/IN)
#   (NP the/DT clouds/NN)
#   ./.
#   (PP As/IN)
#   it/PRP
#   starts/VBZ
#   setting/VBG
#   down/RP
#   ,/,
#   (NP the/DT colour/NN)
#   (PP of/IN)
#   (NP the/DT sky/NN)
#   (NP changes/NNS)
#   to/TO
#   (ADJP a/DT beautiful/JJ)
#   (NP sunset/NN gradient/NN fill/NN)
#   ./.
#   (NP The/DT sun/NN)
#   (NP hides/NNS)
#   (PP behind/IN)
#   (ADJP a/DT few/JJ)
#   (NP clouds/NN)
#   (ADVP again/RB)
#   ,/,
#   and/CC
#   you/PRP
#   can/MD
#   (VP see/VB)
#   (ADJP the/DT light/JJ)
#   scattering/VBG
#   all/DT
#   (ADVP around/RB)
#   ./.
#   You/PRP
#   set/VBP
#   (NP the/DT tripod/NN stand/NN)
#   (PP for/IN)
#   your/PRP$
#   (NP DSLR/NNP)
#   (NP camera/NN)
#   ,/,
#   make/VBP
#   (NP the/DT specifications/NNS)
#   to/TO
#   (VP capture/VB)
#   (NP the/DT moment/NN)
#   ,/,
#   and/CC
#   (VP start/VB)
#   recording/VBG
#   (NP a/DT timelapse/NN)
#   (PP of/IN)
#   (NP the/DT sky/NN)
#   ./.
#   You/PRP
#   (ADVP just/RB)
#   (VP don/VB)
#   (ADJP ’/JJ)
#   (NP t/NN)
#   want/VBP
#   to/TO
#   (VP be/VB)
#   (VP distracted/VBN)
#   (PP by/IN)
#   (NP anything/NN)
#   (ADVP else/RB)
#   ,/,
#   (PP so/IN)
#   you/PRP
#   stop/VBP
#   playing/VBG
#   (NP the/DT songs/NNS)
#   ,/,
#   and/CC
#   (VP enjoy/VB)
#   (NP the/DT silent/NN)
#   ,/,
#   (NP peacef/NN)
#   (ADJP ul/JJ)
#   (NP moment/NN)
#   !/.
#   (ADVP Finally/RB)
#   ,/,
#   (NP the/DT sun/NN)
#   (NP sets/NNS)
#   and/CC
#   (NP brightness/NN)
#   (NP starts/NNS)
#   fading/VBG
#   (ADVP away/RB)
#   (PP as/IN)
#   (NP the/DT night/NN)
#   falls/VBZ
#   ./.
#   You/PRP
#   see/VBP
#   (NP pecks/NNS)
#   (PP of/IN)
#   (NP lights/NNS)
#   (/(
#   (NP stars/NNS)
#   )/)
#   (PP in/IN)
#   (NP the/DT dusk/NN background/NN)
#   ./.
#   You/PRP
#   have/VBP
#   (ADVP never/RB)
#   (VP seen/VBN)
#   (ADVP so/RB)
#   (ADJP many/JJ)
#   (NP stars/NNS)
#   (PP on/IN)
#   (NP nightfall/NN)
#   ,/,
#   and/CC
#   it/PRP
#   (ADVP totally/RB)
#   amazes/VBZ
#   you/PRP
#   ./.
#   You/PRP
#   see/VBP
#   (NP the/DT crescent/NN moon/NN)
#   hovering/VBG
#   (PP over/IN)
#   your/PRP$
#   (NP head/NN)
#   (ADVP so/RB)
#   (ADJP clear/JJ)
#   ,/,
#   (PP that/IN)
#   you/PRP
#   can/MD
#   (VP make/VB)
#   out/RP
#   its/PRP$
#   (NP craters/NNS)
#   !/.
#   You/PRP
#   decide/VBP
#   to/TO
#   (VP take/VB)
#   a/DT
#   closer/JJR
#   (ADJP lo/JJ)
#   (NP ok/NN)
#   and/CC
#   (VP stand/VB)
#   (PP on/IN)
#   (NP the/DT edge/NN)
#   (PP of/IN)
#   (NP the/DT cliff/NN)
#   ./.
#   You/PRP
#   look/VBP
#   down/RP
#   (ADVP upon/RB)
#   (PP at/IN)
#   (NP the/DT pool/NN)
#   (PP of/IN)
#   (NP water/NN)
#   ,/,
#   (ADVP just/RB)
#   to/TO
#   (VP surprise/VB)
#   yourself/PRP
#   (PP with/IN)
#   (NP the/DT presence/NN)
#   (PP of/IN)
#   (ADJP sparkling/JJ)
#   (NP water/NN)
#   ./.
#   (ADVP Later/RB)
#   (PP on/IN)
#   you/PRP
#   realise/VBP
#   (PP that/IN)
#   it/PRP
#   ’/VBZ
#   (NP s/NN))
